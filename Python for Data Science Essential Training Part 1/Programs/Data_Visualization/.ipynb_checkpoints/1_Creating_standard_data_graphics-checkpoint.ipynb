# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Plotting a line chart

# %%
x=range(1,10)
y=np.random.randint(1,10,9)
plt.plot(x,y)

# %% [markdown]
# ### plotting a line chart from a Pandas Object

# %%
path=r"D:\Courses\New folder\Courses\Python for Data Science Essential Training Part 1\Ex_Files_Python_Data_Science_EssT_Pt_1\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\mtcars.csv"

cars=pd.read_csv(path)
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

mpg=cars['mpg']
mpg.plot()
# Out:
# <AxesSubplot:>

# %%
d3=cars[['cyl','mpg','wt']]
d3.plot()

# below code also works
# d3=cars[['cyl','mpg','wt']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### create bar charts

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
mpg.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
mpg.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating Pie Charts

# %%
plt.pie(x)
plt.show()

# %% [markdown]
# ### Saving Plot

# %%
# this will be saved as an png with file_name 'pie_chart_saving' in present working directory

plt.pie(x)
plt.savefig('pie_chart_saving.png')

# %%
#pwd
# %pwd
# Out:
# 'D:\\Courses\\New folder\\Courses\\Python for Data Science Essential Training Part 1\\Programs\\Data_Visualization'
